# %%
import pandas as pd
import twitter

# %%
import twitter
api = twitter.Api(consumer_key="AiqPyRmHkiPhKeEHg",
                  consumer_secret="OWfc3HrZFA7lxVlsEhNF4k6TRhJo9qAzc",
                  access_token_key="263395uwhXWbZA9WQIhz3qRw7kXYsuVC",
                  access_token_secret="Kc9BGOGgIiqLX2eAyPUywnOcwfqMyhvT")

# %%
posts = api.GetUserTimeline(count=100)
# Out:
# [u'nocoding', u'RT @fabriciolopez3: Comunidad, por favor tengan cuidado con paginas como esta https://t.co/NXQ0n5gKL6, es fake, no vayan a donar. RT por fa\u2026', u'@edy_lozano o/', u'Por si utilizan Emacs en Mac y tiene problemas con la tecla Alt \n\nhttps://t.co/mabKfBtVLG', u'git log --all --decorate --oneline --graph\n#aDog #git', u'@TELMEXSoluciona existe alg\xfan problema con internet de modo general?, desde ayer no tenemos conexi\xf3n y las l\xedneas de 01-800 suenan ocupadas', u'A ver si ya deja de cerrarse el MySQLWorkbench en la nueva versi\xf3n 6.3.9, al menos se ve bastante mejor\u2026 #mysql', u'@codebase we were experiencing troubles for about 10 minutes only with git commands (via ssh), after that everything ran normally, thanks!', u'@codebase is down :\u2019(', u'alguien me puede explicar qu\xe9 significa Tlazocamati Allah?', u'Ya veo mi vida en unos y ceros :/ https://t.co/DIzh9H5OUy', u'Para el #MaratonLala disfrutar\xe9 del camino y la compa\xf1\xeda, no voy por t
# ...

# %%
def lexical_diversity(text):
    """
    What is Lexical Diversity?

Lexical Diversity refers to “the range of different words used in a text, with a greater range indicating a higher diversity“
    """
  if len(text) == 0:
    diversity = 0
  else: 
   diversity = float(len(set(text))) / len(text)
  return diversity

# %%
for p in posts:
    print "diversity post " + p.text + "\r"
    print "--- " + str(lexical_diversity(p.text))
# Out:
# diversity post nocoding
# --- 0.75
# diversity post RT @fabriciolopez3: Comunidad, por favor tengan cuidado con paginas como esta https://t.co/NXQ0n5gKL6, es fake, no vayan a donar. RT por fa…
# --- 0.292857142857
# diversity post @edy_lozano o/
# --- 0.857142857143
# diversity post Por si utilizan Emacs en Mac y tiene problemas con la tecla Alt
#
# https://t.co/mabKfBtVLG
# --- 0.359550561798
# diversity post git log --all --decorate --oneline --graph
# #aDog #git
# --- 0.339622641509
# diversity post @TELMEXSoluciona existe algún problema con internet de modo general?, desde ayer no tenemos conexión y las líneas de 01-800 suenan ocupadas
# --- 0.251798561151
# diversity post A ver si ya deja de cerrarse el MySQLWorkbench en la nueva versión 6.3.9, al menos se ve bastante mejor… #mysql
# --- 0.315315315315
# diversity post @codebase we were experiencing troubles for about 10 minutes only with git commands (via ssh), after that everything ran normally, thanks!
# --- 0.224637681159
# ...
